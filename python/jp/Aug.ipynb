# %%
from traitlets import *
import jupyter_skydata as js
from jupyter_skydata import *
from beakerx import *

# %%
x = list(range(5))

# %%
x
# Out:
# ListDisplay(model=[0, 1, 2, 3, 4])

# %%
x.model = list(range(1,5))

# %%
id(x)

# %%
type(x)
# Out:
# jupyter_skydata.example.AugList

# %%
pd.read_csv('D:\\kaggle\\titanic\\train.csv')

# %%
for i in x :
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x = list(range(5))

# %%
type(x)
# Out:
# jupyter_skydata.example.AugList

# %%
list.__class__
# Out:
# type

# %%
type(list)
# Out:
# type

# %%
list.__class__.__name__
# Out:
# 'type'

# %%
x = AugList(range(5))

# %%
type(x)
# Out:
# jupyter_skydata.example.AugList

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
arr = randn(1000)

# %%
hist(arr,10)
# Out:
# (array([   2.,   17.,   77.,  148.,  255.,  269.,  144.,   63.,   20.,    5.]),
#  array([-3.38118579, -2.71540265, -2.04961951, -1.38383637, -0.71805323,
#         -0.05227009,  0.61351305,  1.27929619,  1.94507933,  2.61086247,
#          3.27664561]),
#  <a list of 10 Patch objects>)

# %%
arr = randn(30000)

# %%
arr = arr.reshape([100,-1,3])

# %%
plt.imshow(arr)

# %%
# %matplotlib inline

# %%
plt.imshow(arr)

# %%
arr2 = randn(90000)

# %%
arr2 = arr2.reshape([100,-1,3])

# %%
plt.imshow(arr2)

# %%
# %%bash
# echo $PATH
# Out:
# Couldn't find program: 'bash'
